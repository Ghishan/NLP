# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghishan/NLP/blob/main/Falcon_7B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers accelerate einops

# %%
# !pip install dataset transformers

# %%
from huggingface_hub import notebook_login
notebook_login()

# %% [markdown]
# git lfs is git Large file storage system

# %%
# !apt install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.32.0

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model = "mrm8488/falcoder-7b" #tiiuae/falcon-40b-instruct

tokenizer = AutoTokenizer.from_pretrained(model)

# %% [markdown]
# **Build the Model Pipeline using Hugging Face Transformers Pipeline**

# %%
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
)
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %% [markdown]
# **Our Prompt**

# %%
prompt = "Write a poem about ai progress in pakistan"

# %% [markdown]
# Model Inference using the pipeline that was built above

# %%
sequences = pipeline(
    prompt,
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.

# %%
prompt = "Write a poem about ai progress in pakistan"

# %%
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Result: Write a poem about ai progress in pakistan.
#
# ### Solution:
# Pakistan, the land of pure intellect,
# With its people, a nation of great potential,
# Is now taking leaps in the field of artificial intelligence (AI).
# With the launch of the first state-owned supercomputer in Islamabad, and the creation of the Pakistan Supercomputing Network (PSN) in 2020, Pakistan is now on the road to becoming a technological powerhouse in the region.
# The nation's top scientists and engineers are working tirelessly to create cutting-edge software and hardware, and are making strides in the development of AI systems, autonomous vehicles and even quantum computing.
# The Pakistani government is also heavily investing in educational institutes that teach AI, making this field of knowledge more accessible in Pakistan than in most other countries. As the field advances, Pakistan will continue to lead the way in AI progress, and will eventually become a leader in the field of AI technology.
# ...
